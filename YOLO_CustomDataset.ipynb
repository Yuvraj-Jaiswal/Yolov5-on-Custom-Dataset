# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvraj-Jaiswal/Yolov5-on-Custom-Dataset/blob/main/YOLO_CustomDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# !pip install -U -r yolov5/requirements.txt
# !curl -L "https://app.roboflow.com/ds/psUZzQevkU?key=OaWoiIU7t8" > roboflow.zip;
# !unzip roboflow.zip; rm roboflow.zip

# %%
import tensorflow as tf
print(tf.test.is_gpu_available())
print(tf.test.gpu_device_name())
# Out:
# WARNING:tensorflow:From <ipython-input-1-22abed89115f>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# /device:GPU:0

# %%
# !python yolov5/train.py --img 416 --batch 32 --epochs 1000 --data /content/data.yaml --cfg /content/yolov5/models/yolov5m.yaml --resume /content/runs/train/exp/weights/last.pt
# Out:
# github: skipping check (not a git repository)
# requirements: /content/requirements.txt not found, check failed.
# Resuming training from /content/runs/train/exp/weights/last.pt
# YOLOv5 🚀 v5.0-130-gfdbe527 torch 1.8.1+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='/content/data.yaml', device='', entity=None, epochs=1000, evolve=False, exist_ok=False, global_rank=-1, hyp='./yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='/content/runs/train/exp/weights/last.pt', workers=8, world_size=1)
# ...

# %%
# !python yolov5/detect.py --source /content/drive/MyDrive/Data/Mask_Video  --weights /content/drive/MyDrive/Data/Covid_Mask.pt --conf 0.6

# %%
# %cp /content/runs /content/drive/MyDrive/Data -r
